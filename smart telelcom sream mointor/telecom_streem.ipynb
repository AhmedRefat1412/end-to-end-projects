# %%
import json
import time
from datetime import datetime, timezone
from kafka import KafkaProducer
import random

BOOTSTRAP_SERVERS = "localhost:9092"
TOPIC = "telecom.tower.network"

producer = KafkaProducer(
    bootstrap_servers=BOOTSTRAP_SERVERS,
    key_serializer=lambda k: k.encode("utf-8"),
    value_serializer=lambda v: json.dumps(v).encode("utf-8"),
    acks="all",
    retries=5
)

TOWERS = [
    {"id": "TOWER_1", "region": "Cairo"},
    {"id": "TOWER_2", "region": "Giza"},
    {"id": "TOWER_3", "region": "Alex"}
]

tower_states = {}
for tower in TOWERS:
    tower_states[tower["id"]] = {
        "latency_ms": random.randint(80, 150),
        "throughput_mbps": random.randint(20, 60),
        "packet_loss": round(random.uniform(0, 0.05), 3),
        "active_users": random.randint(50, 200)
    }

print(" Unified Network Metrics Producer Started...")

while True:
    document = {"event_time": datetime.now(timezone.utc).isoformat(), "towers": []}

    for tower in TOWERS:
        state = tower_states[tower["id"]]

        state["latency_ms"] = max(10, state["latency_ms"] + random.randint(-5, 5))
        state["throughput_mbps"] = max(1, state["throughput_mbps"] + random.randint(-5, 5))
        state["packet_loss"] = max(0, round(state["packet_loss"] + random.uniform(-0.01, 0.01), 3))
        state["active_users"] = max(0, state["active_users"] + random.randint(-5, 5))

        tower_doc = {
            "tower_id": tower["id"],
            "region": tower["region"],
            "latency_ms": state["latency_ms"],
            "throughput_mbps": state["throughput_mbps"],
            "packet_loss": state["packet_loss"],
            "active_users": state["active_users"]
        }
        document["towers"].append(tower_doc)

    producer.send(
        topic=TOPIC,
        key="ALL_TOWERS",
        value=document
    )

    print("Sent Unified Network Document:", document)
    time.sleep(10)
# Out:
#  Unified Network Metrics Producer Started...
# Sent Unified Network Document: {'event_time': '2026-02-07T22:06:12.178185+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'latency_ms': 117, 'throughput_mbps': 34, 'packet_loss': 0.029, 'active_users': 184}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'latency_ms': 148, 'throughput_mbps': 32, 'packet_loss': 0.052, 'active_users': 185}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'latency_ms': 149, 'throughput_mbps': 29, 'packet_loss': 0.008, 'active_users': 75}]}
# Sent Unified Network Document: {'event_time': '2026-02-07T22:06:22.298815+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'latency_ms': 117, 'throughput_mbps': 38, 'packet_loss': 0.021, 'active_users': 181}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'latency_ms': 153, 'throughput_mbps': 37, 'packet_loss': 0.057, 'active_users': 190}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'latency_ms': 145, 'throughput_mbps': 25, 'packet_loss': 0.003, 'active_users': 73}]}
# Sent Unified Network Document: {'event_time': '2026-02-07T22:06:32.324641+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'latency_ms': 115, 'throughput_mbps': 38, 'packet_loss': 0.018, 'active_users': 178}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'latency_ms': 154, 'throughput_mbps': 37, 'packet_loss': 0.064, 'active_users': 189}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'latency_ms': 142, 'throughput_mbps': 28, 'packet_loss': 0.005, 'active_users': 70}]}
# Sent Unified Network Document: {'event_time': '2026-02-07T22:06:42.344663+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'latency_ms': 111, 'throughput_mbps': 36, 'packet_loss': 0.009, 'active_users': 173}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'latency_ms': 157, 'throughput_mbps': 35, 'packet_loss': 0.068, 'active_users': 190}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'latency_ms': 138, 'throughput_mbps': 27, 'packet_loss': 0.003, 'active_users': 73}]}
# Sent Unified Network Document: {'event_time': '2026-02-07T22:06:52.366502+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'latency_ms': 115, 'throughput_mbps': 34, 'packet_loss': 0.005, 'active_users': 175}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'latency_ms': 158, 'throughput_mbps': 31, 'packet_loss': 0.074, 'active_users': 194}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'latency_ms': 137, 'throughput_mbps': 29, 'packet_loss': 0, 'active_users': 78}]}
# Sent Unified Network Document: {'event_time': '2026-02-07T22:07:02.378364+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'latency_ms': 118, 'throughput_mbps': 31, 'packet_loss': 0.013, 'active_users': 175}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'latency_ms': 159, 'throughput_mbps': 30, 'packet_loss': 0.08, 'active_users': 194}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'latency_ms': 138, 'throughput_mbps': 29, 'packet_loss': 0, 'active_users': 78}]}
# Sent Unified Network Document: {'event_time': '2026-02-07T22:07:12.392839+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'latency_ms': 120, 'throughput_mbps': 34, 'packet_loss': 0.01, 'active_users': 173}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'latency_ms': 154, 'throughput_mbps': 26, 'packet_loss': 0.088, 'active_users': 196}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'latency_ms': 140, 'throughput_mbps': 24, 'packet_loss': 0, 'active_users': 83}]}
# Sent Unified Network Document: {'event_time': '2026-02-07T22:07:22.402318+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'latency_ms': 124, 'throughput_mbps': 38, 'packet_loss': 0.02, 'active_users': 173}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'latency_ms': 155, 'throughput_mbps': 30, 'packet_loss': 0.081, 'active_users': 192}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'latency_ms': 144, 'throughput_mbps': 20, 'packet_loss': 0, 'active_users': 85}]}
# Sent Unified Network Document: {'event_time': '2026-02-07T22:07:32.416676+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'latency_ms': 125, 'throughput_mbps': 35, 'packet_loss': 0.017, 'active_users': 174}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'latency_ms': 157, 'throughput_mbps': 28, 'packet_loss': 0.086, 'active_users': 197}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'latency_ms': 146, 'throughput_mbps': 17, 'packet_loss': 0, 'active_users': 80}]}
# Sent Unified Network Document: {'event_time': '2026-02-07T22:07:42.433872+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'latency_ms': 120, 'throughput_mbps': 40, 'packet_loss': 0.019, 'active_users': 171}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'latency_ms': 152, 'throughput_mbps': 31, 'packet_loss': 0.077, 'active_users': 195}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'latency_ms': 148, 'throughput_mbps': 20, 'packet_loss': 0, 'active_users': 84}]}
# Sent Unified Network Document: {'event_time': '2026-02-07T22:07:52.446380+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'latency_ms': 119, 'throughput_mbps': 38, 'packet_loss': 0.019, 'active_users': 170}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'latency_ms': 155, 'throughput_mbps': 29, 'packet_loss': 0.087, 'active_users': 198}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'latency_ms': 153, 'throughput_mbps': 18, 'packet_loss': 0.005, 'active_users': 84}]}
# Sent Unified Network Document: {'event_time': '2026-02-07T22:08:02.457349+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'latency_ms': 115, 'throughput_mbps': 43, 'packet_loss': 0.02, 'active_users': 167}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'latency_ms': 159, 'throughput_mbps': 32, 'packet_loss': 0.084, 'active_users': 200}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'latency_ms': 155, 'throughput_mbps': 22, 'packet_loss': 0.006, 'active_users': 81}]}
# Sent Unified Network Document: {'event_time': '2026-02-07T22:08:12.463464+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'latency_ms': 110, 'throughput_mbps': 39, 'packet_loss': 0.018, 'active_users': 167}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'latency_ms': 162, 'throughput_mbps': 30, 'packet_loss': 0.092, 'active_users': 201}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'latency_ms': 151, 'throughput_mbps': 22, 'packet_loss': 0.009, 'active_users': 77}]}
# Sent Unified Network Document: {'event_time': '2026-02-07T22:08:22.474246+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'latency_ms': 111, 'throughput_mbps': 39, 'packet_loss': 0.015, 'active_users': 171}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'latency_ms': 157, 'throughput_mbps': 25, 'packet_loss': 0.093, 'active_users': 201}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'latency_ms': 148, 'throughput_mbps': 21, 'packet_loss': 0.009, 'active_users': 79}]}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 63
#      56 producer.send(
#      57     topic=TOPIC,
#      58     key="ALL_TOWERS",
#      59     value=document
#      60 )
#      62 print("Sent Unified Network Document:", document)
# ---> 63 time.sleep(10)
#
# KeyboardInterrupt:

# %% [markdown]
# create Radio&Cell metrics
# -------------------------

# %%
import json
import time
from datetime import datetime, timezone
from kafka import KafkaProducer
import random

BOOTSTRAP_SERVERS = "localhost:9092"
TOPIC = "telecom.tower.radio"

producer = KafkaProducer(
    bootstrap_servers=BOOTSTRAP_SERVERS,
    key_serializer=lambda k: k.encode("utf-8"),
    value_serializer=lambda v: json.dumps(v).encode("utf-8"),
    acks="all",
    retries=5
)

TOWERS = [
    {"id": "TOWER_1", "region": "Cairo"},
    {"id": "TOWER_2", "region": "Giza"},
    {"id": "TOWER_3", "region": "Alex"}
]

# Stateful
tower_states = {}
for tower in TOWERS:
    tower_states[tower["id"]] = {
        "signal_dbm": random.randint(-110, -90),
        "cell_load_pct": random.randint(30, 60),
        "handover_rate": round(random.uniform(0.0, 2.0), 2),
        "drop_call_rate": round(random.uniform(0.0, 1.0), 2)
    }

print("📡 Unified Radio Metrics Producer Started...")

while True:
    document = {"event_time": datetime.now(timezone.utc).isoformat(), "towers": []}

    for tower in TOWERS:
        state = tower_states[tower["id"]]

        state["signal_dbm"] = max(-120, min(-50, state["signal_dbm"] + random.randint(-2, 2)))
        state["cell_load_pct"] = max(0, min(100, state["cell_load_pct"] + random.randint(-5, 5)))
        state["handover_rate"] = max(0, round(state["handover_rate"] + random.uniform(-0.2, 0.2), 2))
        state["drop_call_rate"] = max(0, round(state["drop_call_rate"] + random.uniform(-0.1, 0.1), 2))

        tower_doc = {
            "tower_id": tower["id"],
            "region": tower["region"],
            "signal_dbm": state["signal_dbm"],
            "cell_load_pct": state["cell_load_pct"],
            "handover_rate": state["handover_rate"],
            "drop_call_rate": state["drop_call_rate"]
        }
        document["towers"].append(tower_doc)

    producer.send(
        topic=TOPIC,
        key="ALL_TOWERS",
        value=document
    )

    print("Sent Unified Radio Document:", document)
    time.sleep(10)

# %% [markdown]
# create Hardware&System metrics
# --------------------

# %%
import json
import time
from datetime import datetime, timezone
from kafka import KafkaProducer
import random

# ===============================
# Kafka Config
# ===============================
BOOTSTRAP_SERVERS = "localhost:9092"
TOPIC = "telecom.tower.system"

producer = KafkaProducer(
    bootstrap_servers=BOOTSTRAP_SERVERS,
    key_serializer=lambda k: k.encode("utf-8"),
    value_serializer=lambda v: json.dumps(v).encode("utf-8"),
    acks="all",
    retries=5
)

# ===============================
# Towers Initial State
# ===============================
TOWERS = [
    {"id": "TOWER_1", "region": "Cairo"},
    {"id": "TOWER_2", "region": "Giza"},
    {"id": "TOWER_3", "region": "Alex"}
]

# لكل tower نخزن state
tower_states = {}
for tower in TOWERS:
    tower_states[tower["id"]] = {
        "cpu_pct": random.randint(20, 40),
        "memory_pct": random.randint(30, 50),
        "power_kw": round(random.uniform(2.5, 3.5), 2),
        "battery_level_pct": random.randint(70, 100)
    }

print("🖥️ Unified System Metrics Producer Started...")

# ===============================
# Streaming Loop
# ===============================
while True:
    document = {"event_time": datetime.now(timezone.utc).isoformat(), "towers": []}

    for tower in TOWERS:
        state = tower_states[tower["id"]]

        # Update each metric gradually
        state["cpu_pct"] = min(100, max(0, state["cpu_pct"] + random.randint(-5, 5)))
        state["memory_pct"] = min(100, max(0, state["memory_pct"] + random.randint(-3, 3)))
        state["power_kw"] = round(max(0, state["power_kw"] + random.uniform(-0.2, 0.2)), 2)
        state["battery_level_pct"] = min(100, max(0, state["battery_level_pct"] - random.uniform(0, 1)))

        # Append tower data to document
        tower_doc = {
            "tower_id": tower["id"],
            "region": tower["region"],
            "cpu_pct": state["cpu_pct"],
            "memory_pct": state["memory_pct"],
            "power_kw": state["power_kw"],
            "battery_level_pct": round(state["battery_level_pct"], 2)
        }
        document["towers"].append(tower_doc)

    # Send unified document as one message
    producer.send(
        topic=TOPIC,
        key="ALL_TOWERS",
        value=document
    )

    print("Sent Unified Document:", document)
    time.sleep(10)
# Out:
# 🖥️ Unified System Metrics Producer Started...
# Sent Unified Document: {'event_time': '2026-02-07T21:35:52.476181+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'cpu_pct': 24, 'memory_pct': 35, 'power_kw': 2.91, 'battery_level_pct': 93.95}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'cpu_pct': 30, 'memory_pct': 35, 'power_kw': 2.86, 'battery_level_pct': 72.24}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'cpu_pct': 45, 'memory_pct': 37, 'power_kw': 2.75, 'battery_level_pct': 88.67}]}
# Sent Unified Document: {'event_time': '2026-02-07T21:36:02.597659+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'cpu_pct': 22, 'memory_pct': 33, 'power_kw': 3.07, 'battery_level_pct': 93.45}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'cpu_pct': 31, 'memory_pct': 33, 'power_kw': 2.72, 'battery_level_pct': 71.58}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'cpu_pct': 47, 'memory_pct': 36, 'power_kw': 2.86, 'battery_level_pct': 87.68}]}
# Sent Unified Document: {'event_time': '2026-02-07T21:36:12.609199+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'cpu_pct': 18, 'memory_pct': 30, 'power_kw': 2.88, 'battery_level_pct': 93.34}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'cpu_pct': 28, 'memory_pct': 31, 'power_kw': 2.77, 'battery_level_pct': 71.09}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'cpu_pct': 52, 'memory_pct': 37, 'power_kw': 2.93, 'battery_level_pct': 87.27}]}
# Sent Unified Document: {'event_time': '2026-02-07T21:36:22.622565+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'cpu_pct': 20, 'memory_pct': 31, 'power_kw': 2.76, 'battery_level_pct': 92.94}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'cpu_pct': 28, 'memory_pct': 30, 'power_kw': 2.67, 'battery_level_pct': 70.33}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'cpu_pct': 57, 'memory_pct': 38, 'power_kw': 2.78, 'battery_level_pct': 86.81}]}
# Sent Unified Document: {'event_time': '2026-02-07T21:36:32.637755+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'cpu_pct': 17, 'memory_pct': 31, 'power_kw': 2.66, 'battery_level_pct': 92.9}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'cpu_pct': 28, 'memory_pct': 32, 'power_kw': 2.78, 'battery_level_pct': 69.86}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'cpu_pct': 62, 'memory_pct': 38, 'power_kw': 2.7, 'battery_level_pct': 86.28}]}
# Sent Unified Document: {'event_time': '2026-02-07T21:36:42.652648+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'cpu_pct': 21, 'memory_pct': 33, 'power_kw': 2.62, 'battery_level_pct': 92.85}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'cpu_pct': 23, 'memory_pct': 34, 'power_kw': 2.78, 'battery_level_pct': 69.72}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'cpu_pct': 63, 'memory_pct': 39, 'power_kw': 2.64, 'battery_level_pct': 85.68}]}
# Sent Unified Document: {'event_time': '2026-02-07T21:36:52.663423+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'cpu_pct': 19, 'memory_pct': 35, 'power_kw': 2.57, 'battery_level_pct': 92.38}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'cpu_pct': 19, 'memory_pct': 37, 'power_kw': 2.67, 'battery_level_pct': 69.65}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'cpu_pct': 68, 'memory_pct': 39, 'power_kw': 2.84, 'battery_level_pct': 84.8}]}
# Sent Unified Document: {'event_time': '2026-02-07T21:37:02.676704+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'cpu_pct': 17, 'memory_pct': 33, 'power_kw': 2.46, 'battery_level_pct': 91.52}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'cpu_pct': 20, 'memory_pct': 40, 'power_kw': 2.56, 'battery_level_pct': 68.77}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'cpu_pct': 65, 'memory_pct': 40, 'power_kw': 2.65, 'battery_level_pct': 84.75}]}
# Sent Unified Document: {'event_time': '2026-02-07T21:37:12.690009+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'cpu_pct': 13, 'memory_pct': 33, 'power_kw': 2.53, 'battery_level_pct': 90.62}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'cpu_pct': 20, 'memory_pct': 37, 'power_kw': 2.52, 'battery_level_pct': 68.71}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'cpu_pct': 60, 'memory_pct': 37, 'power_kw': 2.7, 'battery_level_pct': 84.44}]}
# Sent Unified Document: {'event_time': '2026-02-07T21:37:22.705226+00:00', 'towers': [{'tower_id': 'TOWER_1', 'region': 'Cairo', 'cpu_pct': 9, 'memory_pct': 31, 'power_kw': 2.46, 'battery_level_pct': 89.75}, {'tower_id': 'TOWER_2', 'region': 'Giza', 'cpu_pct': 17, 'memory_pct': 39, 'power_kw': 2.38, 'battery_level_pct': 68.63}, {'tower_id': 'TOWER_3', 'region': 'Alex', 'cpu_pct': 64, 'memory_pct': 36, 'power_kw': 2.82, 'battery_level_pct': 83.54}]}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 76
#      69 producer.send(
#      70     topic=TOPIC,
#      71     key="ALL_TOWERS",
#      72     value=document
#      73 )
#      75 print("Sent Unified Document:", document)
# ---> 76 time.sleep(10)
#
# KeyboardInterrupt:

# %% [markdown]
# create eniveronmental metrics
# ------------------

# %%
import json
import time
from datetime import datetime, timezone
from kafka import KafkaProducer
import random

BOOTSTRAP_SERVERS = "localhost:9092"
TOPIC = "telecom.tower.environment"

producer = KafkaProducer(
    bootstrap_servers=BOOTSTRAP_SERVERS,
    key_serializer=lambda k: k.encode("utf-8"),
    value_serializer=lambda v: json.dumps(v).encode("utf-8"),
    acks="all",
    retries=5
)

TOWERS = [
    {"id": "TOWER_1", "region": "Cairo"},
    {"id": "TOWER_2", "region": "Giza"},
    {"id": "TOWER_3", "region": "Alex"}
]

tower_states = {}
for tower in TOWERS:
    tower_states[tower["id"]] = {
        "temperature_c": random.randint(25, 35),
        "humidity_pct": random.randint(30, 60),
        "wind_speed_kmh": random.randint(5, 20)
    }

print("🌡️ Unified Environment Metrics Producer Started...")

while True:
    document = {"event_time": datetime.now(timezone.utc).isoformat(), "towers": []}

    for tower in TOWERS:
        state = tower_states[tower["id"]]

        state["temperature_c"] = round(state["temperature_c"] + random.uniform(-0.5, 0.5), 1)
        state["humidity_pct"] = round(max(0, min(100, state["humidity_pct"] + random.uniform(-2, 2))), 1)
        state["wind_speed_kmh"] = round(max(0, state["wind_speed_kmh"] + random.uniform(-1, 1)), 1)

        tower_doc = {
            "tower_id": tower["id"],
            "region": tower["region"],
            "temperature_c": state["temperature_c"],
            "humidity_pct": state["humidity_pct"],
            "wind_speed_kmh": state["wind_speed_kmh"]
        }
        document["towers"].append(tower_doc)

    producer.send(
        topic=TOPIC,
        key="ALL_TOWERS",
        value=document
    )

    print("Sent Unified Environment Document:", document)
    time.sleep(10)
# Out:
# 🌡️ Environment Metrics Producer Started...
# Sent: {'event_time': '2026-02-07T21:01:05.443607+00:00', 'tower_id': 'TOWER_3', 'region': 'Alex', 'temperature_c': 48, 'humidity_pct': 59, 'wind_speed_kmh': 7.06}
# Sent: {'event_time': '2026-02-07T21:01:15.710575+00:00', 'tower_id': 'TOWER_2', 'region': 'Giza', 'temperature_c': 27, 'humidity_pct': 40, 'wind_speed_kmh': 15.56}
# Sent: {'event_time': '2026-02-07T21:01:34.872674+00:00', 'tower_id': 'TOWER_2', 'region': 'Giza', 'temperature_c': 24, 'humidity_pct': 78, 'wind_speed_kmh': 22.27}
# Sent: {'event_time': '2026-02-07T21:01:44.887503+00:00', 'tower_id': 'TOWER_1', 'region': 'Cairo', 'temperature_c': 30, 'humidity_pct': 80, 'wind_speed_kmh': 37.07}
# Sent: {'event_time': '2026-02-07T21:01:54.905011+00:00', 'tower_id': 'TOWER_1', 'region': 'Cairo', 'temperature_c': 43, 'humidity_pct': 78, 'wind_speed_kmh': 27.73}
# Sent: {'event_time': '2026-02-07T21:02:04.919533+00:00', 'tower_id': 'TOWER_1', 'region': 'Cairo', 'temperature_c': 38, 'humidity_pct': 32, 'wind_speed_kmh': 18.6}
# Sent: {'event_time': '2026-02-07T21:02:14.944144+00:00', 'tower_id': 'TOWER_3', 'region': 'Alex', 'temperature_c': 39, 'humidity_pct': 28, 'wind_speed_kmh': 27.2}
# Sent: {'event_time': '2026-02-07T21:02:24.962700+00:00', 'tower_id': 'TOWER_3', 'region': 'Alex', 'temperature_c': 40, 'humidity_pct': 32, 'wind_speed_kmh': 9.87}
# Sent: {'event_time': '2026-02-07T21:02:34.974634+00:00', 'tower_id': 'TOWER_2', 'region': 'Giza', 'temperature_c': 46, 'humidity_pct': 37, 'wind_speed_kmh': 17.49}
# Sent: {'event_time': '2026-02-07T21:02:44.993843+00:00', 'tower_id': 'TOWER_1', 'region': 'Cairo', 'temperature_c': 30, 'humidity_pct': 38, 'wind_speed_kmh': 1.86}
# Sent: {'event_time': '2026-02-07T21:02:55.007003+00:00', 'tower_id': 'TOWER_3', 'region': 'Alex', 'temperature_c': 26, 'humidity_pct': 49, 'wind_speed_kmh': 15.45}
# Sent: {'event_time': '2026-02-07T21:03:05.021637+00:00', 'tower_id': 'TOWER_2', 'region': 'Giza', 'temperature_c': 44, 'humidity_pct': 51, 'wind_speed_kmh': 14.61}
# Sent: {'event_time': '2026-02-07T21:03:15.033172+00:00', 'tower_id': 'TOWER_2', 'region': 'Giza', 'temperature_c': 50, 'humidity_pct': 43, 'wind_speed_kmh': 25.11}
# Sent: {'event_time': '2026-02-07T21:03:25.041999+00:00', 'tower_id': 'TOWER_3', 'region': 'Alex', 'temperature_c': 44, 'humidity_pct': 49, 'wind_speed_kmh': 38.78}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 45
#      38 producer.send(
#      39     topic=TOPIC,
#      40     key=tower["id"],
#      41     value=event
#      42 )
#      44 print("Sent:", event)
# ---> 45 time.sleep(10)
#
# KeyboardInterrupt:

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, from_json, explode
from pyspark.sql.types import *

# Create Spark Session with Kafka support
spark = SparkSession.builder \
    .appName("TelecomStreamingConsumer") \
    .getOrCreate()

spark.sparkContext.setLogLevel("WARN")

#  Read Stream From Kafka
df_kafka = spark.readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "localhost:9092") \
    .option("subscribe", "telecom.tower.system") \
    .option("startingOffsets", "latest") \
    .load()

# 3️⃣ Convert value from binary → string
df_string = df_kafka.selectExpr("CAST(value AS STRING)")

# 4️⃣ Define JSON Schema
schema = StructType([
    StructField("event_time", StringType()),
    StructField("towers", ArrayType(
        StructType([
            StructField("tower_id", StringType()),
            StructField("region", StringType()),
            StructField("cpu_pct", IntegerType()),
            StructField("memory_pct", IntegerType()),
            StructField("power_kw", DoubleType()),
            StructField("battery_level_pct", DoubleType())
        ])
    ))
])

# 5️⃣ Parse JSON
df_json = df_string.select(
    from_json(col("value"), schema).alias("data")
)

# 6️⃣ Explode towers array
df_exploded = df_json.select(
    col("data.event_time"),
    explode(col("data.towers")).alias("tower")
)

df_final = df_exploded.select(
    "event_time",
    "tower.tower_id",
    "tower.region",
    "tower.cpu_pct",
    "tower.memory_pct",
    "tower.power_kw",
    "tower.battery_level_pct"
)

# 7️⃣ Write To Console (اختبار)
query = df_final.writeStream \
    .outputMode("append") \
    .format("console") \
    .start()

query.awaitTermination()

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import from_json, col
from pyspark.sql.types import StructType, StructField, StringType, ArrayType, MapType

# =========================================
# 1️⃣ Spark Session
# =========================================
spark = SparkSession.builder \
    .appName("TelecomTowerRawDocuments") \
    .getOrCreate()

spark.sparkContext.setLogLevel("WARN")

# =========================================
# 2️⃣ Generic Document Schema
# =========================================

tower_schema = MapType(StringType(), StringType())

document_schema = StructType([
    StructField("event_time", StringType()),
    StructField("towers", ArrayType(tower_schema))
])

# =========================================
# 3️⃣ Function to Read Any Topic
# =========================================

def read_topic(topic_name):
    df = spark.readStream \
        .format("kafka") \
        .option("kafka.bootstrap.servers", "localhost:9092") \
        .option("subscribe", topic_name) \
        .option("startingOffsets", "latest") \
        .load()

    parsed_df = df.selectExpr("CAST(value AS STRING) as json_str") \
        .select(from_json(col("json_str"), document_schema).alias("data")) \
        .select("data.*")

    return parsed_df

# =========================================
# 4️⃣ Read All 4 Streams
# =========================================

system_df = read_topic("telecom.tower.system")
radio_df = read_topic("telecom.tower.radio")
env_df = read_topic("telecom.tower.environment")
network_df = read_topic("telecom.tower.network")

# =========================================
# 5️⃣ Output Each Stream to Console
# =========================================

query1 = system_df.writeStream \
    .outputMode("append") \
    .format("console") \
    .option("truncate", False) \
    .start()

query2 = radio_df.writeStream \
    .outputMode("append") \
    .format("console") \
    .option("truncate", False) \
    .start()

query3 = env_df.writeStream \
    .outputMode("append") \
    .format("console") \
    .option("truncate", False) \
    .start()

query4 = network_df.writeStream \
    .outputMode("append") \
    .format("console") \
    .option("truncate", False) \
    .start()

spark.streams.awaitAnyTermination()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/02/15 22:16:08 WARN Utils: Your hostname, refat, resolves to a loopback address: 127.0.1.1; using 10.0.2.15 instead (on interface enp0s3)
# 26/02/15 22:16:08 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/15 22:16:17 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[1], line 47
#      41     return parsed_df
#      43 # =========================================
#      44 # 4️⃣ Read All 4 Streams
#      45 # =========================================
# ---> 47 system_df = read_topic("telecom.tower.system")
#      48 radio_df = read_topic("telecom.tower.radio")
#      49 env_df = read_topic("telecom.tower.environment")
#
# Cell In[1], line 35, in read_topic(topic_name)
#      29 def read_topic(topic_name):
#      30     df = spark.readStream \
#      31         .format("kafka") \
#      32         .option("kafka.bootstrap.servers", "localhost:9092") \
#      33         .option("subscribe", topic_name) \
#      34         .option("startingOffsets", "latest") \
# ---> 35         .load()
#      37     parsed_df = df.selectExpr("CAST(value AS STRING) as json_str") \
#      38         .select(from_json(col("json_str"), document_schema).alias("data")) \
#      39         .select("data.*")
#      41     return parsed_df
#
# File ~/miniconda3/envs/spark/lib/python3.10/site-packages/pyspark/sql/streaming/readwriter.py:307, in DataStreamReader.load(self, path, format, schema, **options)
#     305     return self._df(self._jreader.load(path))
#     306 else:
# --> 307     return self._df(self._jreader.load())
#
# File ~/miniconda3/envs/spark/lib/python3.10/site-packages/py4j/java_gateway.py:1362, in JavaMember.__call__(self, *args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
#    1361 answer = self.gateway_client.send_command(command)
# -> 1362 return_value = get_return_value(
#    1363     answer, self.gateway_client, self.target_id, self.name)
#    1365 for temp_arg in temp_args:
#    1366     if hasattr(temp_arg, "_detach"):
#
# File ~/miniconda3/envs/spark/lib/python3.10/site-packages/pyspark/errors/exceptions/captured.py:269, in capture_sql_exception.<locals>.deco(*a, **kw)
#     265 converted = convert_exception(e.java_exception)
#     266 if not isinstance(converted, UnknownException):
#     267     # Hide where the exception came from that shows a non-Pythonic
#     268     # JVM exception message.
# --> 269     raise converted from None
#     270 else:
#     271     raise
#
# AnalysisException: Failed to find data source: kafka. Please deploy the application as per the deployment section of Structured Streaming + Kafka Integration Guide.
